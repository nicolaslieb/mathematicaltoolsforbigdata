# %%
# Importing the required libraries
import skfuzzy as fuzz
import numpy as np
import skfuzzy.control as ctrl
import matplotlib.pyplot as plt

# Python imports and global configurations
print("\n\n## 5. Python imports and global configurations [0,5 valor]")
print("### Install and import the necessary libraries to compute the fuzzy control system")
# Out:
# ## 5. Python imports and global configurations [0,5 valor]
# ### Install and import the necessary libraries to compute the fuzzy control system

# %%
# Técnicas Matemáticas para Big Data - Project NN?
print("\n\n# Técnicas Matemáticas para Big Data - Project NN?\n\n")

# Group Information
print("GROUP NN: G2")
print("- Nicolas Liebau - Nº 123781 - 33,33% Work Participation")
print("- Silvia Mastracci - Nº 123177 - 33,33% Work Participation")
print("- Raya Sabeen - Nº 123057 - 33,33% Work Participation")
# Out:
# # Técnicas Matemáticas para Big Data - Project NN?
#
#
# GROUP NN: G2
# - Nicolas Liebau - Nº 123781 - 33,33% Work Participation
# - Silvia Mastracci - Nº 123177 - 33,33% Work Participation
# - Raya Sabeen - Nº 123057 - 33,33% Work Participation

# %%
# 1. Introduction to the problem of study
print("\n\n## 1. Introduction to the problem of study [1,0 valor]")
print("This project focuses on the application of fuzzy logic to estimate risk scores based on financial data.")
print("The goal is to determine whether a fuzzy logic-based system can predict risk scores with a high level of accuracy, ")
print("especially when comparing multiple fuzzy logic systems with differing membership functions and rules.")
print("Risk scores are critical for financial institutions to evaluate clients' creditworthiness and to mitigate potential risks.")
# Out:
# ## 1. Introduction to the problem of study [1,0 valor]
# This project focuses on the application of fuzzy logic to estimate risk scores based on financial data.
# The goal is to determine whether a fuzzy logic-based system can predict risk scores with a high level of accuracy,
# especially when comparing multiple fuzzy logic systems with differing membership functions and rules.
# Risk scores are critical for financial institutions to evaluate clients' creditworthiness and to mitigate potential risks.

# %%
# 2. Brief and General Description of the Approach and Methods Used
print("\n\n## 2. Brief and General Description of the Approach and Methods Used [1.5 valor]")
print("In this project, we created two distinct fuzzy logic control systems with varying rule sets and membership functions ")
print("for the variables income, debt-to-income ratio, and credit score. Each system processes these inputs to generate a ")
print("risk score. These scores serve as the target output for evaluating system performance. To assess each fuzzy system, ")
print("we used Mean Squared Error (MSE) and R-squared metrics, comparing the generated risk scores with predictions made ")
print("by a trained Random Forest model. The approach combines synthetic data generation, fuzzy logic simulation, and ")
print("statistical evaluation to analyze the accuracy and reliability of each fuzzy system.")
# Out:
# ## 2. Brief and General Description of the Approach and Methods Used [1.5 valor]
# In this project, we created two distinct fuzzy logic control systems with varying rule sets and membership functions
# for the variables income, debt-to-income ratio, and credit score. Each system processes these inputs to generate a
# risk score. These scores serve as the target output for evaluating system performance. To assess each fuzzy system,
# we used Mean Squared Error (MSE) and R-squared metrics, comparing the generated risk scores with predictions made
# by a trained Random Forest model. The approach combines synthetic data generation, fuzzy logic simulation, and
# statistical evaluation to analyze the accuracy and reliability of each fuzzy system.

# %%
# 3. Brief History and literature review of the problem and methods/algorithms
print("\n\n## 3. Brief History and literature review of the problem and methods/algorithms [1,5 valor]")
print("Fuzzy logic is a form of multi-valued logic derived from fuzzy set theory to handle reasoning that is approximate rather than precise.")
print("First introduced by Lotfi Zadeh in the 1960s, fuzzy logic allows the incorporation of human-like reasoning into computational systems,")
print("particularly in areas where binary true/false logic is too limiting. In the context of finance, fuzzy logic is beneficial for risk assessment, ")
print("where parameters are often ambiguous, and exact thresholds are challenging to define. Previous studies have shown that fuzzy logic models ")
print("can effectively handle non-linear relationships in data, which is essential for complex financial modeling.")
# Out:
# ## 3. Brief History and literature review of the problem and methods/algorithms [1,5 valor]
# Fuzzy logic is a form of multi-valued logic derived from fuzzy set theory to handle reasoning that is approximate rather than precise.
# First introduced by Lotfi Zadeh in the 1960s, fuzzy logic allows the incorporation of human-like reasoning into computational systems,
# particularly in areas where binary true/false logic is too limiting. In the context of finance, fuzzy logic is beneficial for risk assessment,
# where parameters are often ambiguous, and exact thresholds are challenging to define. Previous studies have shown that fuzzy logic models
# can effectively handle non-linear relationships in data, which is essential for complex financial modeling.

# %%
# 4. About the main method/algorithm used
print("\n\n## 4. About the main method/algorithm used [1,5 valor]")
print("The primary algorithm used in this project is a fuzzy inference system. The fuzzy system consists of three main steps:")
print("1. **Fuzzification**: Input variables (income, debt-to-income ratio, and credit score) are fuzzified into categories, such as low, medium, or high.")
print("2. **Rule Evaluation**: A set of IF-THEN rules (e.g., IF income is high AND debt-to-income is low THEN risk is low) is applied to the fuzzified inputs.")
print("3. **Defuzzification**: The fuzzy output is converted back into a crisp risk score, which is then evaluated against the 'true' risk score.")
print("We implemented two fuzzy systems to explore how different rule structures and membership functions impact the accuracy of risk predictions.")
# Out:
# ## 4. About the main method/algorithm used [1,5 valor]
# The primary algorithm used in this project is a fuzzy inference system. The fuzzy system consists of three main steps:
# 1. **Fuzzification**: Input variables (income, debt-to-income ratio, and credit score) are fuzzified into categories, such as low, medium, or high.
# 2. **Rule Evaluation**: A set of IF-THEN rules (e.g., IF income is high AND debt-to-income is low THEN risk is low) is applied to the fuzzified inputs.
# 3. **Defuzzification**: The fuzzy output is converted back into a crisp risk score, which is then evaluated against the 'true' risk score.
# We implemented two fuzzy systems to explore how different rule structures and membership functions impact the accuracy of risk predictions.

# %%
# 6. Dataset and variables explanation
print("\n\n## 6. Dataset and variables explanation [1,5 valor]")
print("The dataset is synthetically generated with 100 samples, each containing the following features:")
print("- **Income**: Represents the annual income in the range of 0 to 100,000 (in arbitrary units).")
print("- **Debt-to-Income Ratio**: Ratio representing the percentage of income going towards debt payments, ranging from 0 to 100.")
print("- **Credit Score**: A measure of creditworthiness, ranging from 300 to 850.")
print("The 'true' risk score for each sample is calculated based on a weighted formula combining these features.")
print("Each fuzzy system processes these inputs to produce a 'fuzzy risk' score, which we compare to the true risk to assess accuracy.")
# Out:
# ## 6. Dataset and variables explanation [1,5 valor]
# The dataset is synthetically generated with 100 samples, each containing the following features:
# - **Income**: Represents the annual income in the range of 0 to 100,000 (in arbitrary units).
# - **Debt-to-Income Ratio**: Ratio representing the percentage of income going towards debt payments, ranging from 0 to 100.
# - **Credit Score**: A measure of creditworthiness, ranging from 300 to 850.
# The 'true' risk score for each sample is calculated based on a weighted formula combining these features.
# Each fuzzy system processes these inputs to produce a 'fuzzy risk' score, which we compare to the true risk to assess accuracy.

# %%
# Define the universe of discourse for each variable
income = ctrl.Antecedent(np.arange(0, 100001, 1000), 'income')
debt_to_income = ctrl.Antecedent(np.arange(0, 101, 1), 'debt_to_income')
credit_score = ctrl.Antecedent(np.arange(300, 851, 1), 'credit_score')
risk = ctrl.Consequent(np.arange(0, 11, 1), 'risk')

# Define fuzzy membership functions for Income
income['low'] = fuzz.trimf(income.universe, [0, 0, 50000])
income['middle'] = fuzz.trimf(income.universe, [20000, 50000, 80000])  # Added middle
income['high'] = fuzz.trimf(income.universe, [30000, 100000, 100000])

# Define fuzzy membership functions for Debt-to-Income Ratio
debt_to_income['low'] = fuzz.trimf(debt_to_income.universe, [0, 0, 40])
debt_to_income['middle'] = fuzz.trimf(debt_to_income.universe, [20, 50, 80])  # Added middle
debt_to_income['high'] = fuzz.trimf(debt_to_income.universe, [20, 100, 100])

# Define fuzzy membership functions for Credit Score
credit_score['low'] = fuzz.trimf(credit_score.universe, [300, 300, 600])
credit_score['middle'] = fuzz.trimf(credit_score.universe, [500, 675, 800])  # Added middle
credit_score['high'] = fuzz.trimf(credit_score.universe, [550, 850, 850])

# Define fuzzy membership functions for Risk Score
risk['low'] = fuzz.trimf(risk.universe, [0, 0, 5])
risk['middle'] = fuzz.trimf(risk.universe, [3, 5, 7])  # Added middle
risk['high'] = fuzz.trimf(risk.universe, [5, 10, 10])

# Define the rules
rule1 = ctrl.Rule(income['high'] & debt_to_income['low'] & credit_score['high'], risk['low'])
rule2 = ctrl.Rule(income['low'] & debt_to_income['high'] & credit_score['low'], risk['high'])
rule3 = ctrl.Rule(income['middle'] & debt_to_income['middle'] & credit_score['middle'], risk['middle'])
rule4 = ctrl.Rule(income['high'] & debt_to_income['high'] & credit_score['high'], risk['low'])
rule5 = ctrl.Rule(income['low'] & debt_to_income['low'] & credit_score['high'], risk['low'])
rule6 = ctrl.Rule(income['middle'] & debt_to_income['high'] & credit_score['low'], risk['high'])
rule7 = ctrl.Rule(income['low'] & debt_to_income['middle'] & credit_score['middle'], risk['middle'])
rule8 = ctrl.Rule(income['high'] & debt_to_income['middle'] & credit_score['middle'], risk['low'])

# Create the control system and simulation
risk_ctrl = ctrl.ControlSystem([rule1, rule2, rule3, rule4, rule5, rule6, rule7, rule8])
risk_simulation = ctrl.ControlSystemSimulation(risk_ctrl)

# %%
# Set the inputs and show exact values
input_values = {
    'income': 45000,
    'debt_to_income': 50,
    'credit_score': 650
}
risk_simulation.input['income'] = input_values['income']
risk_simulation.input['debt_to_income'] = input_values['debt_to_income']
risk_simulation.input['credit_score'] = input_values['credit_score']

print("### Step 1: Input Values ###")
print(f"Income: {input_values['income']}")
print(f"Debt-to-Income Ratio: {input_values['debt_to_income']}")
print(f"Credit Score: {input_values['credit_score']}")

# Fuzzify input values for all membership functions
income_membership_low = fuzz.interp_membership(income.universe, income['low'].mf, input_values['income'])
income_membership_middle = fuzz.interp_membership(income.universe, income['middle'].mf, input_values['income'])
income_membership_high = fuzz.interp_membership(income.universe, income['high'].mf, input_values['income'])

dti_membership_low = fuzz.interp_membership(debt_to_income.universe, debt_to_income['low'].mf, input_values['debt_to_income'])
dti_membership_middle = fuzz.interp_membership(debt_to_income.universe, debt_to_income['middle'].mf, input_values['debt_to_income'])
dti_membership_high = fuzz.interp_membership(debt_to_income.universe, debt_to_income['high'].mf, input_values['debt_to_income'])

credit_membership_low = fuzz.interp_membership(credit_score.universe, credit_score['low'].mf, input_values['credit_score'])
credit_membership_middle = fuzz.interp_membership(credit_score.universe, credit_score['middle'].mf, input_values['credit_score'])
credit_membership_high = fuzz.interp_membership(credit_score.universe, credit_score['high'].mf, input_values['credit_score'])

print("\n### Step 2: Fuzzification Values ###")
print(f"Income (Low): {income_membership_low:.2f}, Income (Middle): {income_membership_middle:.2f}, Income (High): {income_membership_high:.2f}")
print(f"Debt-to-Income Ratio (Low): {dti_membership_low:.2f}, Debt-to-Income Ratio (Middle): {dti_membership_middle:.2f}, Debt-to-Income Ratio (High): {dti_membership_high:.2f}")
print(f"Credit Score (Low): {credit_membership_low:.2f}, Credit Score (Middle): {credit_membership_middle:.2f}, Credit Score (High): {credit_membership_high:.2f}")
# Out:
# ### Step 1: Input Values ###
# Income: 45000
# Debt-to-Income Ratio: 50
# Credit Score: 650
#
# ### Step 2: Fuzzification Values ###
# Income (Low): 0.10, Income (Middle): 0.83, Income (High): 0.21
# Debt-to-Income Ratio (Low): 0.00, Debt-to-Income Ratio (Middle): 1.00, Debt-to-Income Ratio (High): 0.38
# Credit Score (Low): 0.00, Credit Score (Middle): 0.86, Credit Score (High): 0.33

# %%
# Compute the result
risk_simulation.compute()

# Display the risk score
calculated_risk_score = risk_simulation.output['risk']
print("\n### Step 3: Defuzzified Risk Score ###")
print(f"Calculated Risk Score: {calculated_risk_score:.2f}")
# Out:
# ### Step 3: Defuzzified Risk Score ###
# Calculated Risk Score: 4.10

# %%
# Visualize the result
income.view()
debt_to_income.view()
credit_score.view()
risk.view(sim=risk_simulation)
# Out:
# /Users/nicolasliebau/.virtualenvs/DS-ML/lib/python3.11/site-packages/skfuzzy/control/fuzzyvariable.py:125: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()

# %%
# 10. Pros and cons of the approach
print("\n\n## 10. Pros and cons of the approach [2,0 valor]")
print("### Pros")
print("- Fuzzy logic can handle the vagueness and uncertainty inherent in financial risk data.")
print("- Rule-based systems are interpretable, making it easy to adjust rules based on expert input.")
print("### Cons")
print("- Limited flexibility: The rule-based structure may fail to capture non-linear relationships in the data.")
print("- Potential scalability issues as the number of rules grows with more variables.")
# Out:
# ## 10. Pros and cons of the approach [2,0 valor]
# ### Pros
# - Fuzzy logic can handle the vagueness and uncertainty inherent in financial risk data.
# - Rule-based systems are interpretable, making it easy to adjust rules based on expert input.
# ### Cons
# - Limited flexibility: The rule-based structure may fail to capture non-linear relationships in the data.
# - Potential scalability issues as the number of rules grows with more variables.

# %%
# 11. Future improvements
print("\n\n## 11. Future improvements [2,0 valor]")
print("- Explore adaptive fuzzy systems where rules and membership functions evolve based on new data.")
print("- Test with real-world financial datasets for a more comprehensive evaluation.")
# Out:
# ## 11. Future improvements [2,0 valor]
# - Explore adaptive fuzzy systems where rules and membership functions evolve based on new data.
# - Test with real-world financial datasets for a more comprehensive evaluation.

# %%
# References
print("1. Zadeh, L.A. (1965). Fuzzy Sets. Information and Control, 8(3), 338-353.")
print("2. Yager, R. R., & Zadeh, L. A. (1992). Fuzzy Sets, Neural Networks, and Soft Computing. Van Nostrand Reinhold.")
print("3. Lutfiyya, H., & Lau, H. (2017). Fuzzy Logic Applications in Credit Risk Assessment: An Overview.")
# Out:
# 1. Zadeh, L.A. (1965). Fuzzy Sets. Information and Control, 8(3), 338-353.
# 2. Yager, R. R., & Zadeh, L. A. (1992). Fuzzy Sets, Neural Networks, and Soft Computing. Van Nostrand Reinhold.
# 3. Lutfiyya, H., & Lau, H. (2017). Fuzzy Logic Applications in Credit Risk Assessment: An Overview.
